# %%
pval_ttest_lastframe_cols = ["infected-count-lastframe-t-test-pvalue", "area-lastframe-t-test-pvalue", "radial-velocity-lastframe-t-test-pvalue"]
pval_ztest_lastframe_cols = ["infected-count-lastframe-z-test-pvalue", "area-lastframe-z-test-pvalue", "radial-velocity-lastframe-z-test-pvalue"]
pval_corxi2_lastframe_cols = ["infected-count-lastframe-corxi2-pval", "area-lastframe-corxi2-pval", "radial-velocity-lastframe-corxi2-pval"]
pval_corxi2_cols = ["infected-count-corxi2-pval", "area-corxi2-pval", "radial-velocity-corxi2-pval"]
zscore_sums_cols = ["zscores-normalized-sum", "zscores-lastframe-normalized-sum"]
circularity_cols = ["circularity-lastframe-mean"]

params = ["randomwalk_speed", "c2c_k", "c2c_x0", "c2c_radius"]

# %%
import pandas as pd
from utils import *

eval_csv = "/Users/ashkanhzdr/workspace/infectio-mesa/output/dVGFdF11/0_evaluation/bulk_evaluate.csv"

df = read_and_clean_df(eval_csv)
df = add_param_cols_from_experiment_name(df)

# %% [markdown]
# ## scores in one plot

# %%
df.columns.values
# Out:
# array(['experiment_name', 'infected-count-zscore',
#        'infected-count-zscore-mean', 'infected-count-lastframe-zscore',
#        'infected-count-lastframe-zscore-mean',
#        'infected-count-corxi2-pval',
#        'infected-count-lastframe-corxi2-pval',
#        'infected-count-lastframe-t-test-pvalue',
#        'infected-count-lastframe-z-test-pvalue', 'area-zscore',
#        'area-zscore-mean', 'area-lastframe-zscore',
#        'area-lastframe-zscore-mean', 'area-corxi2-pval',
#        'area-lastframe-corxi2-pval', 'area-lastframe-t-test-pvalue',
#        'area-lastframe-z-test-pvalue', 'radial-velocity-zscore',
#        'radial-velocity-zscore-mean', 'radial-velocity-lastframe-zscore',
#        'radial-velocity-lastframe-zscore-mean',
#        'radial-velocity-corxi2-pval',
#        'radial-velocity-lastframe-corxi2-pval',
#        'radial-velocity-lastframe-t-test-pvalue',
#        'radial-velocity-lastframe-z-test-pvalue', 'circularity-lastframe',
#        'zscores-normalized-sum', 'zscores-lastframe-normalized-sum',
#        'circularity-lastframe-mean', 'randomwalk_speed', 'c2c_k',
#        'c2c_x0', 'c2c_radius'], dtype=object)

# %%
dotted_plot_overlaying_scores(df, "randomwalk_speed", ['zscores-lastframe-normalized-sum', "circularity-lastframe-mean"])
dotted_plot_overlaying_scores(df, "randomwalk_speed", ['infected-count-lastframe-t-test-pvalue', "circularity-lastframe-mean"], xlim=(0, 10.5))

# %% [markdown]
# # Individual plots

# %%
params = ["randomwalk_speed", "c2c_k", "c2c_x0", "c2c_radius"]
scores = zscore_sums_cols + pval_ttest_lastframe_cols + pval_ztest_lastframe_cols

for param in params:
    create_dotted_plot(df, param, scores)

# %%
dotted_plot_overlaying_scores(df, "randomwalk_speed", ["infected-count-zscore-mean", 'area-zscore-mean', 'radial-velocity-zscore-mean', ])
